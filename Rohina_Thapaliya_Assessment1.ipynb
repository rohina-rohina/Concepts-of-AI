# %% [markdown]
# # Problem - 1: Getting Started with Data Exploration - Some Warm up Exercises:

# %% [markdown]
# ## 1. Data Exploration and Understanding:

# %% [markdown]
# ### • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/L5CGAI/Assessment1
# Out:
# /content/drive/MyDrive/L5CGAI/Assessment1

# %%
# !ls
# Out:
# middle_east_dataset.csv		    south_asia_dataset.csv
# Rohina_Thapaliya_Assessment1.ipynb  WHR-2024-5CS037.csv

# %%
import numpy as np
import pandas as pd

df=pd.read_csv('WHR-2024-5CS037.csv')

# %%
df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 2. Identify the number of rows and columns in the dataset.

# %%
rows, cols= df.shape

print("The number of rows is: ", rows)
print("The number of columns is: ", cols)
# Out:
# The number of rows is:  143
# The number of columns is:  9

# %% [markdown]
# 3. List all the columns and their data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  143 non-null    object
#  1   score                         143 non-null    float64
#  2   Log GDP per capita            140 non-null    float64
#  3   Social support                140 non-null    float64
#  4   Healthy life expectancy       140 non-null    float64
#  5   Freedom to make life choices  140 non-null    float64
#  6   Generosity                    140 non-null    float64
#  7   Perceptions of corruption     140 non-null    float64
#  8   Dystopia + residual           140 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 10.2+ KB

# %% [markdown]
# ###• Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.

# %%
df.describe()
# Out:
#             score  Log GDP per capita  Social support  \
# count  143.000000          140.000000      140.000000
# mean     5.527580            1.378807        1.134329
# std      1.170717            0.425098        0.333317
# min      1.721000            0.000000        0.000000
# 25%      4.726000            1.077750        0.921750
# 50%      5.785000            1.431500        1.237500
# 75%      6.416000            1.741500        1.383250
# max      7.741000            2.141000        1.617000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               140.000000                    140.000000  140.000000
# mean                  0.520886                      0.620621    0.146271
# std                   0.164923                      0.162492    0.073441
# min                   0.000000                      0.000000    0.000000
# 25%                   0.398000                      0.527500    0.091000
# ...

# %%
mean_score=df['score'].mean()
median_score=df['score'].median()
standard_deviation_score=df['score'].std()

print("The mean is: ", mean_score)
print("The median is: ", median_score)
print("The Standard deviation is: ", standard_deviation_score)
# Out:
# The mean is:  5.52758041958042
# The median is:  5.785
# The Standard deviation is:  1.1707165099442995

# %% [markdown]
# 2. Identify the country with the highest and lowest happiness scores.

# %%
high_score= df.loc[df['score'].idxmax(), 'Country name']
low_score= df.loc[df['score'].idxmin(), 'Country name']

print("The country with highest happiness score is: ", high_score)
print("The country with lowest happiness score is: ", low_score)
# Out:
# The country with highest happiness score is:  Finland
# The country with lowest happiness score is:  Afghanistan

# %% [markdown]
# • Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
missing_val= df.isnull().sum()
print("Missing value per column is: \n", missing_val)
# Out:
# Missing value per column is:
#  Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.

# %%
filtered_data= df[df['score']>7.5]
print(filtered_data)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %% [markdown]
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
sorted_data=filtered_data.sort_values(by='Log GDP per capita', ascending=False)
print(sorted_data.head(10))
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# • Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

# %%
def happiness_category(score):
  if score<4:
    return "Low"
  elif 4<= score <= 6:
    return "Medium"
  else:
    return "High"

df['Happiness Category']=df['score'].apply(happiness_category)
print(df[['Country name', 'score', 'Happiness Category']])
# Out:
#          Country name  score Happiness Category
# 0             Finland  7.741               High
# 1             Denmark  7.583               High
# 2             Iceland  7.525               High
# 3              Sweden  7.344               High
# 4              Israel  7.341               High
# ..                ...    ...                ...
# 138  Congo (Kinshasa)  3.295                Low
# 139      Sierra Leone  3.245                Low
# 140           Lesotho  3.186                Low
# 141           Lebanon  2.707                Low
# 142       Afghanistan  1.721                Low
#
# [143 rows x 3 columns]

# %% [markdown]
# ## 2. Data Visualizations:
#
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_10_happiest= df.nlargest(10, 'score')
plt.figure(figsize=(15,5))
sns.barplot(x='Country name', y='score', data=top_10_happiest)
plt.title("Top 10 Happiest Country")
plt.show()

# %% [markdown]
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
top_10_unhappiest=df.nsmallest(10, 'score')
plt.figure(figsize=(15,5))
plt.plot(top_10_unhappiest['Country name'], top_10_unhappiest['score'], marker='o', color='green')
plt.title("Top 10 unhappiest countries")
plt.show()

# %% [markdown]
# • Plot a histogram for the Score column to show its distribution and also interpret.

# %%
plt.figure(figsize=(15,5))
sns.histplot(df['score'], bins=15, kde=True, color='purple')
plt.title("Happiness Score Distribution")
plt.show()

# %% [markdown]
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x='Log GDP per capita', y='score', data=df, hue='Happiness Category')
plt.title('GDP per capita v/s Happiness Score')
plt.show()

# %% [markdown]
# # Problem - 2 - Some Advance Data Exploration Task:

# %% [markdown]
# ##Task - 1 - Setup Task - Preparing the South-Asia Dataset:

# %% [markdown]
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
import pandas as pd

south_asian_countries= {"Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"}

south_asia_data= df[df['Country name'].isin(south_asian_countries)]

south_asia_data.to_csv('south_asia_dataset.csv', index= False)
print("Saved as a csv file")
# Out:
# Saved as a csv file

# %% [markdown]
# ##Task - 2 - Composite Score Ranking:

# %% [markdown]
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support + 0.30 × Healthy Life Expectancy

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

south_asia_dataset= pd.read_csv('south_asia_dataset.csv')

south_asia_data.loc[:, 'Composite Score'] = (
    0.40 * south_asia_data["Log GDP per capita"] +
    0.30 * south_asia_data["Social support"] +
    0.30 * south_asia_data["Healthy life expectancy"]
)

print(south_asia_data.head(3))
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
#
#      Perceptions of corruption  Dystopia + residual Happiness Category  \
# 92                       0.115                1.783             Medium
# 107                      0.074                1.907             Medium
# 125                      0.122                0.756             Medium
#
#      Composite Score
# 92            0.8159
# 107           0.7039
# 125           0.7874
# <ipython-input-71-a54987945a69>:7: SettingWithCopyWarning:
# ...

# %% [markdown]
# 2. Rank the South Asian countries based on the Composite Score in descending order.

# %%
south_asia_data= south_asia_data.sort_values(by='Composite Score', ascending= False)
south_asia_data['Rank'] = range(1, len(south_asia_data)+1)

print(south_asia_data[['Country name', 'Composite Score', 'Rank']])
# Out:
#     Country name  Composite Score  Rank
# 127    Sri Lanka           1.0739     1
# 92         Nepal           0.8159     2
# 125        India           0.7874     3
# 107     Pakistan           0.7039     4
# 128   Bangladesh           0.6774     5
# 142  Afghanistan           0.3238     6

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.

# %%
top_5_countries = south_asia_data.head(5)
plt.figure(figsize=(10,6))
sns.barplot(x='Composite Score', y='Country name', data=top_5_countries, palette='Blues_d')
plt.title("Top 5 Asian Countries by Composite Score")
plt.xlabel('Composite Score')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-73-27466e6a26ea>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Composite Score', y='Country name', data=top_5_countries, palette='Blues_d')

# %% [markdown]
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your discussion with some visualization plot.

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='score', y='Composite Score', data=south_asia_data, hue='Country name', palette='Set2', s=100)
plt.title('Comparision of original vs compostite score')
plt.xlabel('Original Happiness Score')
plt.ylabel('Composite Score')
plt.legend(title='Country')
plt.show()

# %% [markdown]
# ##Task - 3 - Outlier Detection:
#
# **Tasks**:

# %% [markdown]
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

south_asia_dataset= pd.read_csv('south_asia_dataset.csv')

def detect_outliers(df, column):
  Q1= df[column].quantile(0.25)
  Q3= df[column].quantile(0.75)
  IQR= Q3-Q1
  lower_bound= Q1-1.5*IQR
  upper_bound= Q3+1.5*IQR
  outliers= df[(df[column]<lower_bound) | (df[column]>upper_bound)]
  return outliers

score_outliers= detect_outliers(south_asia_dataset, 'score')
gdp_outliers= detect_outliers(south_asia_dataset, 'Log GDP per capita')

outliers= pd.concat([score_outliers, gdp_outliers]).drop_duplicates()

print("Outlier Countries: ")
outliers[['Country name', 'score', 'Log GDP per capita']]
# Out:
# Outlier Countries:
#   Country name  score  Log GDP per capita
# 5  Afghanistan  1.721               0.628

# %% [markdown]
# 2. Define outliers using the 1.5 × IQR rule.

# %% [markdown]
# Outliers are points that deviate from the rest a data set in the sense that they are beyond acceptable distance. Outliers are declared using 1.5 × IQR rule by excluding any value whether below Q1 - 1.5 × IQR or above Q3 + 1.5 × IQR where Q1 is the first quartile, Q3 is the third quartile and IQR is the interquartile range, which is Q3 - Q1.

# %% [markdown]
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers in a different color.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))

sns.scatterplot(
    x='Log GDP per capita', y='score', data=south_asia_data,
    color='blue', label='South Asian Countries'
)

sns.scatterplot(
    x='Log GDP per capita', y='score', data=outliers,
    color='red', label='Outliers', s=100, edgecolor='black'
)

plt.title('Outlier Detection: GDP per Capita vs Score')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.legend()
plt.show()

# %% [markdown]
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
print("Characteristics of Outliers:")
for _, row in outliers.iterrows():
    print(
        f"Country: {row['Country name']}, "
        f"Score: {row['score']}, "
        f"Log GDP per Capita: {row['Log GDP per capita']}"
    )
# Out:
# Characteristics of Outliers:
# Country: Afghanistan, Score: 1.721, Log GDP per Capita: 0.628

# %% [markdown]
# ## Task - 4 - Exploring Trends Across Metrics:

# %% [markdown]
# **Tasks:**

# %% [markdown]
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation {pearson correlation} with the Score for South Asian countries.

# %%
freedom_correlation = south_asia_data['Freedom to make life choices'].corr(south_asia_data['score'], method='pearson')
generosity_correlation = south_asia_data['Generosity'].corr(south_asia_data['score'], method='pearson')

print(f"Correlation between Freedom to Make Life Choices and Score: {freedom_correlation:.2f}")
print(f"Correlation between Generosity and Score: {generosity_correlation:.2f}")
# Out:
# Correlation between Freedom to Make Life Choices and Score: 0.80
# Correlation between Generosity and Score: 0.87

# %% [markdown]
# 2. Create scatter plots with trendlines for these metrics against the Score.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.regplot(
    x='Freedom to make life choices', y='score',
    data=south_asia_data, scatter_kws={'color': 'blue'}, line_kws={'color': 'green'}
)
plt.title('Freedom to Make Life Choices vs. Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Happiness Score')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.regplot(
    x='Generosity', y='score',
    data=south_asia_data, scatter_kws={'color': 'green'}, line_kws={'color': 'green'}
)
plt.title('Generosity vs. Score')
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.show()

# %% [markdown]
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
if abs(freedom_correlation) > abs(generosity_correlation):
    stronger_metric = "Freedom to Make Life Choices"
    weaker_metric = "Generosity"
    strongest_corr = freedom_correlation
    weakest_corr = generosity_correlation
else:
    stronger_metric = "Generosity"
    weaker_metric = "Freedom to Make Life Choices"
    strongest_corr = generosity_correlation
    weakest_corr = freedom_correlation

print(f"The strongest relationship is between {stronger_metric} and Score with a correlation of {strongest_corr:.2f}.")
print(f"The weakest relationship is between {weaker_metric} and Score with a correlation of {weakest_corr:.2f}.")
# Out:
# The strongest relationship is between Generosity and Score with a correlation of 0.87.
# The weakest relationship is between Freedom to Make Life Choices and Score with a correlation of 0.80.

# %% [markdown]
# ## Task - 5 - Gap Analysis:

# %% [markdown]
# **Tasks:**

# %% [markdown]
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score for each South Asian country.

# %%
south_asia_data['GDP-Score Gap'] = south_asia_data['Log GDP per capita'] - south_asia_data['score']
print(south_asia_data[['Country name', 'Log GDP per capita', 'score', 'GDP-Score Gap']])
# Out:
#     Country name  Log GDP per capita  score  GDP-Score Gap
# 127    Sri Lanka               1.361  3.898         -2.537
# 92         Nepal               0.965  5.158         -4.193
# 125        India               1.166  4.054         -2.888
# 107     Pakistan               1.069  4.657         -3.588
# 128   Bangladesh               1.122  3.886         -2.764
# 142  Afghanistan               0.628  1.721         -1.093

# %% [markdown]
# 2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
ranked_ascending = south_asia_data.sort_values(by='GDP-Score Gap', ascending=True)
print("-------------------Ascending Order:---------------------\n\n")
print("Top 3 countries with the largest negative GDP-Score Gaps:")
print(ranked_ascending[['Country name', 'GDP-Score Gap']].head(3))
# Out:
# -------------------Ascending Order:---------------------
#
#
# Top 3 countries with the largest negative GDP-Score Gaps:
#     Country name  GDP-Score Gap
# 92         Nepal         -4.193
# 107     Pakistan         -3.588
# 125        India         -2.888

# %%
ranked_descending = south_asia_data.sort_values(by='GDP-Score Gap', ascending=False)
print("-------------------Descending Order:---------------------\n\n")
print("Top 3 countries with the largest positive GDP-Score Gaps:")
print(ranked_descending[['Country name', 'GDP-Score Gap']].head(3))
# Out:
# -------------------Descending Order:---------------------
#
#
# Top 3 countries with the largest positive GDP-Score Gaps:
#     Country name  GDP-Score Gap
# 142  Afghanistan         -1.093
# 127    Sri Lanka         -2.537
# 128   Bangladesh         -2.764

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

largest_positive_gaps = ranked_descending.head(3)
largest_negative_gaps = ranked_ascending.head(3)

top_gaps = pd.concat([largest_positive_gaps, largest_negative_gaps])

plt.figure(figsize=(10, 6))
sns.barplot(
    x='GDP-Score Gap', y='Country name',
    data=top_gaps, palette='coolwarm'
)
plt.title('Top 3 Largest Positive and Negative GDP-Score Gaps')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country')
plt.axvline(0, color='black', linestyle='--', linewidth=0.8)
plt.show()
# Out:
# <ipython-input-85-ef8ad77c278b>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
print("Analysis of Top Gaps:")
print(top_gaps[['Country name', 'Log GDP per capita', 'score', 'GDP-Score Gap']])
# Out:
# Analysis of Top Gaps:
#     Country name  Log GDP per capita  score  GDP-Score Gap
# 142  Afghanistan               0.628  1.721         -1.093
# 127    Sri Lanka               1.361  3.898         -2.537
# 128   Bangladesh               1.122  3.886         -2.764
# 92         Nepal               0.965  5.158         -4.193
# 107     Pakistan               1.069  4.657         -3.588
# 125        India               1.166  4.054         -2.888

# %% [markdown]
# # Problem - 3 - Comparative Analysis:

# %% [markdown]
# ## Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:

# %% [markdown]
# **Tasks:**
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the following list:
#
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
# "United Arab Emirates", "Yemen"]
#
# Complete the following task:

# %%
middle_east_countries = [
    "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait",
    "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia",
    "Syria", "United Arab Emirates", "Yemen"
]
middle_east_data = df[df['Country name'].isin(middle_east_countries)]

middle_east_data.to_csv('middle_east_dataset.csv', index=False)

print(middle_east_data[['Country name', 'score', 'Log GDP per capita']])
# Out:
#              Country name  score  Log GDP per capita
# 4                  Israel  7.341               1.803
# 12                 Kuwait  6.951               1.845
# 21   United Arab Emirates  6.733               1.983
# 27           Saudi Arabia  6.594               1.842
# 61                Bahrain  5.959                 NaN
# 91                   Iraq  5.166               1.249
# 99                   Iran  4.923               1.435
# 124                Jordan  4.186               1.262
# 132                 Yemen  3.561               0.671
# 141               Lebanon  2.707               1.377

# %% [markdown]
# 1. Descriptive Statistics:
#
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
#
# • Which region has higher happiness Scores on average?

# %%
south_asia_mean = south_asia_data['score'].mean()
south_asia_std = south_asia_data['score'].std()

middle_east_mean = middle_east_data['score'].mean()
middle_east_std = middle_east_data['score'].std()

print(f"South Asia - Mean: {south_asia_mean:.2f}, Std Dev: {south_asia_std:.2f}")
print(f"Middle East - Mean: {middle_east_mean:.2f}, Std Dev: {middle_east_std:.2f}")

if south_asia_mean > middle_east_mean:
    print("South Asia has a higher average happiness score.")
else:
    print("Middle East has a higher average happiness score.")
# Out:
# South Asia - Mean: 3.90, Std Dev: 1.18
# Middle East - Mean: 5.41, Std Dev: 1.57
# Middle East has a higher average happiness score.

# %% [markdown]
# 2. Top and Bottom Performers:
#
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_3_south_asia = south_asia_data.nlargest(3, 'score')
bottom_3_south_asia = south_asia_data.nsmallest(3, 'score')

top_3_middle_east = middle_east_data.nlargest(3, 'score')
bottom_3_middle_east = middle_east_data.nsmallest(3, 'score')

print("Top 3 South Asian Countries:\n", top_3_south_asia[['Country name', 'score']])
print("Bottom 3 South Asian Countries:\n", bottom_3_south_asia[['Country name', 'score']])

print("Top 3 Middle Eastern Countries:\n", top_3_middle_east[['Country name', 'score']])
print("Bottom 3 Middle Eastern Countries:\n", bottom_3_middle_east[['Country name', 'score']])

combined_top = pd.concat([top_3_south_asia, top_3_middle_east])
combined_bottom = pd.concat([bottom_3_south_asia, bottom_3_middle_east])

# Top performers
plt.figure(figsize=(10, 6))
sns.barplot(x='score', y='Country name', data=combined_top)
plt.title('Top 3 Performers by Region')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()
# Out:
# Top 3 South Asian Countries:
#      Country name  score
# 92         Nepal  5.158
# 107     Pakistan  4.657
# 125        India  4.054
# Bottom 3 South Asian Countries:
#      Country name  score
# 142  Afghanistan  1.721
# 128   Bangladesh  3.886
# 127    Sri Lanka  3.898
# Top 3 Middle Eastern Countries:
#              Country name  score
# 4                 Israel  7.341
# 12                Kuwait  6.951
# 21  United Arab Emirates  6.733
# Bottom 3 Middle Eastern Countries:
#      Country name  score
# 141      Lebanon  2.707
# 132        Yemen  3.561
# 124       Jordan  4.186

# %%
# Bottom performers
plt.figure(figsize=(10, 6))
sns.barplot(x='score', y='Country name', data=combined_bottom)
plt.title('Bottom 3 Performers by Region')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# 3. Metric Comparisons:
#
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy between the regions using grouped bar charts.
#
# • Which metrics show the largest disparity between the two regions?

# %%
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
comparison_data = pd.concat([
    south_asia_data[metrics].mean().rename('South Asia'),
    middle_east_data[metrics].mean().rename('Middle East')
], axis=1)

comparison_data.plot(kind='bar', figsize=(10, 6))
plt.title('Metric Comparison of South Asia and Middle East')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.show()

largest_disparity_metric = comparison_data.abs().diff(axis=1).idxmax()
print(f"The metric with largest disparity is {largest_disparity_metric[0]}.")
# Out:
# The metric with largest disparity is nan.
# <ipython-input-91-73185ad16e9f>:13: FutureWarning: The behavior of DataFrame.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   largest_disparity_metric = comparison_data.abs().diff(axis=1).idxmax()
# <ipython-input-91-73185ad16e9f>:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"The metric with largest disparity is {largest_disparity_metric[0]}.")

# %% [markdown]
# 4. Happiness Disparity:
#
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
# • Which region has greater variability in happiness?

# %%
sa_range = south_asia_data['score'].max() - south_asia_data['score'].min()
me_range = middle_east_data['score'].max() - middle_east_data['score'].min()

sa_cv = south_asia_data['score'].std() / south_asia_data['score'].mean()
me_cv = middle_east_data['score'].std() / middle_east_data['score'].mean()

print(f"South Asia - Range: {sa_range:.2f}, CV: {sa_cv:.2f}")
print(f"Middle East - Range: {me_range:.2f}, CV: {me_cv:.2f}")

if sa_cv > me_cv:
    print("South Asia has greater variability in happiness.")
else:
    print("Middle East has greater variability in happiness.")
# Out:
# South Asia - Range: 3.44, CV: 0.30
# Middle East - Range: 4.63, CV: 0.29
# South Asia has greater variability in happiness.

# %% [markdown]
# 5. Correlation Analysis:
#
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and Generosity within each region.
#
# • Create scatter plots to visualize and interpret the relationships.

# %%
south_asia_corr = south_asia_data[['Freedom to make life choices', 'Generosity', 'score']].corr()
middle_east_corr = middle_east_data[['Freedom to make life choices', 'Generosity', 'score']].corr()

print("South Asia Correlation:\n", south_asia_corr['score'])
print("**************************************************************************************")
print("Middle East Correlation:\n", middle_east_corr['score'])

plt.figure(figsize=(8, 6))
sns.heatmap(south_asia_corr, annot=True)
plt.title("South Asia Correlation Heatmap")
plt.show()
print("**************************************************************************************")
plt.figure(figsize=(8, 6))
sns.heatmap(middle_east_corr, annot=True)
plt.title("Middle East Correlation Heatmap")
plt.show()
print("**************************************************************************************")



for region, data in [("South Asia", south_asia_data), ("Middle East", middle_east_data)]:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x='Freedom to make life choices', y='score', data=data, label='Freedom')
    print("**************************************************************************************")
    sns.scatterplot(x='Generosity', y='score', data=data, label='Generosity')
    plt.title(f"Score Correlations in {region}")
    plt.legend()
    plt.show()
# Out:
# South Asia Correlation:
#  Freedom to make life choices    0.800519
# Generosity                      0.874512
# score                           1.000000
# Name: score, dtype: float64
# **************************************************************************************
# Middle East Correlation:
#  Freedom to make life choices    0.863220
# Generosity                      0.627524
# score                           1.000000
# Name: score, dtype: float64
# **************************************************************************************
# **************************************************************************************
# **************************************************************************************
# **************************************************************************************

# %% [markdown]
# 6. Outlier Detection:
#
# • Identify outlier countries in both regions based on Score and GDP per Capita.
#
# • Plot these outliers and discuss their implications.

# %%
outliers_sa = detect_outliers(south_asia_data, 'score')
outliers_me = detect_outliers(middle_east_data, 'score')

# Plot outliers
plt.figure(figsize=(10, 6))
sns.scatterplot(data=south_asia_data, x='Log GDP per capita', y='score', label='South Asia', color='blue')
sns.scatterplot(data=middle_east_data, x='Log GDP per capita', y='score', label='Middle East', color='green')
sns.scatterplot(data=outliers_sa, x='Log GDP per capita', y='score', label='SA Outliers', color='red', s=100)
sns.scatterplot(data=outliers_me, x='Log GDP per capita', y='score', label='ME Outliers', color='orange', s=100)
plt.title('Outliers in South Asia and Middle East')
plt.legend()
plt.show()

# %% [markdown]
# 7. Visualization:
#
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
south_asia_data.loc[:, 'Region'] = 'South Asia'
middle_east_data.loc[:, 'Region'] = 'Middle East'

combined_df = pd.concat([south_asia_data[['score', 'Region']],
                         middle_east_data[['score', 'Region']]],
                        ignore_index=True)

plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=combined_df,hue='Region', palette='Set1')

plt.title('Comparison of Happiness Score Distributions between South Asia and the Middle East')
plt.xlabel('Region')
plt.ylabel('Happiness Score')

plt.show()
# Out:
# <ipython-input-95-94c6f1df2911>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   middle_east_data.loc[:, 'Region'] = 'Middle East'
